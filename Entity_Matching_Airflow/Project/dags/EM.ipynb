# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os

# %%
def load_df(filename, file_path='../data'):
    full_path = os.path.join(file_path, f'{filename}.csv')
    try:
        df = pd.read_csv(full_path)
        print(f"File '{filename}.csv' loaded successfully from '{file_path}'.")
        return df
    except FileNotFoundError:
        print(f"Error: The file '{filename}.csv' was not found in the directory '{file_path}'.")
    except pd.errors.EmptyDataError:
        print(f"Error: The file '{filename}.csv' is empty.")
    except pd.errors.ParserError:
        print(f"Error: The file '{filename}.csv' could not be parsed.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# %%
layout1 = load_df('ABC_layout_1')
layout2 = load_df('PQR_layout_2')
layout3 = load_df('layout_3_voters')
layout4 = load_df('KLM_layout_4')
layout5 = load_df('layout_5_license_dropped')

layout1 = layout1.rename(columns={"First Name": "Name", "Father Name": "Father_Name", "Permanent_Adress":"Permanent_Address"})
layout2 = layout2.rename(columns = {"Customer_ID": "Mobile Number"})
layout3 = layout3.rename(columns={"votersName": "Name", "votersFatherName": "Father_Name", "votersMotherName": "Mother Name", " Gender": "Gender", "Permanent_Adress":"Permanent_Address"})
layout4 = layout4.rename(columns={"Father Name": "Father_Name"})

del layout1["Last Name"]
del layout2["Unnamed: 0"]
del layout4["Unnamed: 0"]
# Out:
# File 'ABC_layout_1.csv' loaded successfully from '../data'.
# File 'PQR_layout_2.csv' loaded successfully from '../data'.
# File 'layout_3_voters.csv' loaded successfully from '../data'.
# File 'KLM_layout_4.csv' loaded successfully from '../data'.
# File 'layout_5_license_dropped.csv' loaded successfully from '../data'.

# %%
def sanitize(df):
    return df.map(lambda x: x.replace(',', '').replace(' ', '').strip() if isinstance(x, str) else '' if pd.isna(x) else x)

# %%
layouts = [layout1, layout2, layout3, layout4, layout5]

# %%
layout_copies = []
for layout in layouts:
    try:
        if layout is not None:
            sanitized_layout = sanitize(layout.copy())
            layout_copies.append(sanitized_layout)
        else:
            layout_copies.append(None)
    except Exception as e:
        print(f"An error occurred while sanitizing a layout: {e}")
        layout_copies.append(None)

# %%
for i in range(len(layout_copies)):
    layout_copies[i] = sanitize(layout_copies[i])

# %%
def create_soup(df, df_, soup, soup_name):
    df[soup_name] = df_[soup].apply(lambda x: ' '.join(x.values.astype(str)).lower(), axis=1)

soup = ['Name', 'Date of Birth', 'Father_Name']

for i, j, k, in zip(layouts, layout_copies, range(len(layouts))):
    create_soup(i, j, soup, f"soup{k+1}")

# %%
def combine(A, B, soup_A, soup_B, threshold=0.3):
    # Initialize the TF-IDF Vectorizer
    tfidf = TfidfVectorizer(stop_words='english')
    
    # Combine the textual data for fitting the TF-IDF model
    combined_soup = pd.concat([A[soup_A], B[soup_B]], ignore_index=True)
    tfidf.fit(combined_soup)
    
    # Transform the textual data into TF-IDF matrices
    tfidf_matrix_A = tfidf.transform(A[soup_A])
    tfidf_matrix_B = tfidf.transform(B[soup_B])
    
    # Compute cosine similarity between the two matrices
    similarity = cosine_similarity(tfidf_matrix_A, tfidf_matrix_B)
    similarity_df = pd.DataFrame(similarity, index=A.index, columns=B.index)
    
    # Determine the index of the most similar row in B for each row in A
    max_idx_row = similarity_df.idxmax(axis=1)
    similarity_mask = similarity_df.max(axis=1) >= threshold
    
    # Initialize the combined DataFrame with A, ensuring all columns from both DataFrames
    combined_columns = list(set(A.columns) | set(B.columns))
    combined_data = pd.DataFrame(columns=combined_columns)
    
    # Merge the similar rows 
    for idx_A in A.index:
        if similarity_mask[idx_A]:
            idx_B = max_idx_row[idx_A]
            combined_row = A.loc[idx_A].combine_first(B.loc[idx_B])
        else:
            combined_row = A.loc[idx_A]
        combined_data = pd.concat([combined_data, combined_row.to_frame().T], ignore_index=True)
    
    # Append non-similar rows from B to A
    new_records = B.loc[~B.index.isin(max_idx_row[similarity_mask].values)]
    result = pd.concat([combined_data, new_records], ignore_index=True)
    result.drop(columns=soup_B, inplace=True)
    return result

result_12 = combine(layout1, layout2, 'soup1', 'soup2')
result_123 = combine(result_12, layout3, 'soup1', 'soup3')
result_1234 = combine(result_123, layout4, 'soup1', 'soup4')
final_result = combine(result_1234, layout5, 'soup1', 'soup5')

# %%
final_result
# Out:
#    Mobile Number       SpouseName  votersID Date of Birth votersAge  \
# 0     1234567890       Sita Thapa  11116874    1990-01-01        45
# 1     2345678901      Ravi Sharma  22259363    1991-02-02        38
# 2     3456789012    Maya Adhikari  33385241    1992-03-03        52
# 3     4567890123        Surya Rai  44475489    1993-04-04        30
# 4     5678901234     Sarita Karki  55562139    1994-05-05        27
# 5     6789012345     Pemba Gurung  66698214    1995-06-06        41
# 6     7890123456   Laxmi Shrestha  77714635    1996-07-07        36
# 7     8901234567     Raj Maharjan  88847326    1997-08-08        50
# 8     9012345678      Pema Tamang  99953421    1998-09-09        43
# 9      123456789        Manish KC  10103847    1999-10-10        34
# 10    1234567800     Nisha Khadka  11113982    2000-11-11        39
# 11    2345678902      Kamal Magar  12122547    2001-12-12        48
# 12    3456789013       Sita Yadav  13135698    1989-01-13        31
# 13    4567890124       Mina Bista  14147652    1988-02-14        29
# 14    5678901235       Ram Dhakal  15158963    1987-03-15        44
# 15    6789012346       Radha Pant  16169852    1986-04-16        53
# 16    7890123457       Amit Joshi  17175246    1985-05-17        37
# 17    8901234568  Anita Bhattarai  18183569    1984-06-18        28
# 18    9012345679      Sanu Gurung  19194258    1983-07-19        46
# 19     123456790        Hari Lama  20205417    1982-08-20        40
#
#    Customer Code             Name Blood Group              Father_Name  \
# 0       21216874        Ram Thapa         AB+        Ram Bahadur Thapa
# 1       22359363    Sita Shrestha         AB-     Hari Prasad Shrestha
# 2       33485241      Hari Gurung          B-     Gopal Krishna Gurung
# 3       45475489      Gita Tamang          A-         Shyam Lal Tamang
# 4       56562139       Mohan Lama          A+         Krishna Raj Lama
# 5       67698214      Radha Magar          B-      Narayan Kumar Magar
# 6       78714635      Krishna Rai         AB+      Govinda Bahadur Rai
# 7       89847326    Sarita Sherpa          A-     Shiva Narayan Sherpa
# 8       91953421     Bikash Karki          B-  Bhagirath Bahadur Karki
# 9       10203847   Nisha Bhandari          A-   Surya Bahadur Bhandari
# 10      12113982   Aarav Adhikari          O+   Rajan Bahadur Adhikari
# 11      13122547      Sneha Joshi         AB+     Ramesh Bahadur Joshi
# 12      13235698     Pratik Shahi          O-       Suresh Kumar Shahi
# 13      14247652   Anju Bhattarai         AB-     Dinesh Raj Bhattarai
# 14      15158964  Manish Maharjan          B+   Bijay Bahadur Maharjan
# 15      16169853          Puja KC         AB-        Ramesh Bahadur KC
# 16      17375246      Anil Khadka         AB-    Rajesh Bahadur Khadka
# 17      18383569       Rita Rimal          B-     Ganesh Bahadur Rimal
# 18      19294258  Pratiksha Dahal         AB+    Santosh Bahadur Dahal
# 19      20305417  Dipesh Pokharel          A-    Shyam Sundar Pokharel
#
#                         Permanent_Address Customer ID      Mother Name  \
# 0             Baluwatar, Kathmandu, Nepal        3245      Laxmi Thapa
# 1                Lakeside, Pokhara, Nepal        3246     Radha Sharma
# 2   Chitwan National Park, Chitwan, Nepal        3247    Gita Adhikari
# 3               Biratnagar, Morang, Nepal        3248         Mina Rai
# 4               Bharatpur, Chitwan, Nepal        3249    Kalpana Karki
# 5                Butwal, Rupandehi, Nepal        3250      Nima Gurung
# 6               Hetauda, Makwanpur, Nepal        3251    Saru Shrestha
# 7                Janakpur, Dhanusa, Nepal        3252    Nanu Maharjan
# 8                 Nepalgunj, Banke, Nepal        3253     Lhamu Tamang
# 9                  Dharan, Sunsari, Nepal        3254          Lila KC
# 10                Birtamode, Jhapa, Nepal        3255   Chandra Khadka
# 11              Dhangadhi, Kailali, Nepal        3256     Tulasa Magar
# 12                Itahari, Sunsari, Nepal        3257      Ganga Yadav
# 13            Bhaktapur, Bhaktapur, Nepal        3258     Sunita Bista
# 14             Kirtipur, Kathmandu, Nepal        3259      Gita Dhakal
# 15              Lalitpur, Lalitpur, Nepal        3260       Laxmi Pant
# 16                   Ghorahi, Dang, Nepal        3261     Sarita Joshi
# 17                   Tansen, Palpa, Nepal        3262  Meena Bhattarai
# 18                  Bidur, Nuwakot, Nepal        3263     Manju Gurung
# 19                    Damak, Jhapa, Nepal        3264        Rita Lama
#
#     SC Number  PAN_Number                                           soup1  \
# 0   001.01.01  ABCDE1234F             ramthapa 1990-01-01 rambahadurthapa
# 1   001.01.02  FGHIJ5678K      sitashrestha 1991-02-02 hariprasadshrestha
# 2   001.01.03  LMNOP9012L        harigurung 1992-03-03 gopalkrishnagurung
# 3   001.01.04  QRSTU3456M            gitatamang 1993-04-04 shyamlaltamang
# 4   001.01.05  VWXYZ7890N             mohanlama 1994-05-05 krishnarajlama
# 5   001.01.06  ABCD1234PQ         radhamagar 1995-06-06 narayankumarmagar
# 6   001.01.07  EFGH5678RS         krishnarai 1996-07-07 govindabahadurrai
# 7   001.01.08  TUVW9012XY      saritasherpa 1997-08-08 shivanarayansherpa
# 8   001.01.09  ZABC3456DE    bikashkarki 1998-09-09 bhagirathbahadurkarki
# 9   001.01.10  FGHI7890JK   nishabhandari 1999-10-10 suryabahadurbhandari
# 10  001.01.11  LMNO1234PL   aaravadhikari 2000-11-11 rajanbahaduradhikari
# 11  001.01.12  QRST5678UM        snehajoshi 2001-12-12 rameshbahadurjoshi
# 12  001.01.13  VWXY9012NZ         pratikshahi 1989-01-13 sureshkumarshahi
# 13  001.01.14  ABCD3456OP     anjubhattarai 1988-02-14 dineshrajbhattarai
# 14  001.01.15  EFGH7890QR  manishmaharjan 1987-03-15 bijaybahadurmaharjan
# 15  001.01.16  STUV1234WX               pujakc 1986-04-16 rameshbahadurkc
# 16  001.01.17  YZAB5678CD       anilkhadka 1985-05-17 rajeshbahadurkhadka
# 17  001.01.18  EFGH9012EF         ritarimal 1984-06-18 ganeshbahadurrimal
# 18  001.01.19  IJKL3456GH   pratikshadahal 1983-07-19 santoshbahadurdahal
# 19  001.01.20  MNOP7890IJ   dipeshpokharel 1982-08-20 shyamsundarpokharel
#
#                   Temporary_Address      Citizenship Number National Id  \
# 0         Gongabu, Kathmandu, Nepal  624-93227-32431/660086      AB123C
# 1          New Road, Pokhara, Nepal  747-42087-31417/584714      DE456F
# 2         Pulchowk, Lalitpur, Nepal  389-45382-93886/821590      GH789I
# 3        Bagbazar, Kathmandu, Nepal  571-38785-99733/440035      JK012L
# 4        Balkumari, Lalitpur, Nepal  864-17331-40021/961722      MN345O
# 5        Chabahil, Kathmandu, Nepal  033-51347-62581/380746      PQ678R
# 6       Kumaripati, Lalitpur, Nepal  068-37653-84341/852787      ST901U
# 7   New Baneshwor, Kathmandu, Nepal  323-37869-95909/623481      VW234X
# 8          Boudha, Kathmandu, Nepal  406-94259-70142/249811      YZ567A
# 9         Kalanki, Kathmandu, Nepal  272-28301-42325/881177      BC890D
# 10          Sanepa, Lalitpur, Nepal  575-80644-44438/883300      EF123G
# 11    Putalisadak, Kathmandu, Nepal  599-66155-86484/518801      HI456J
# 12        Tinkune, Kathmandu, Nepal  371-38746-28131/634277      KL789M
# 13     Sinamangal, Kathmandu, Nepal  506-21915-16175/214975      NO012P
# 14         Thamel, Kathmandu, Nepal  157-92240-30969/930555      QR345S
# 15      Jawalakhel, Lalitpur, Nepal  697-65333-88172/166613      TU678V
# 16      Maitighar, Kathmandu, Nepal  395-60019-88104/590785      WX901Y
# 17    Buddhanagar, Kathmandu, Nepal  542-42953-82512/112038      ZA234B
# 18          Naxal, Kathmandu, Nepal  697-25014-99353/663054      CD567E
# 19       Gaushala, Kathmandu, Nepal  769-44973-94012/456699      FG890H
#
#     Gender  License Number
# 0     Male  15-05-58353205
# 1   Female  21-08-00435579
# 2     Male  93-12-35351480
# 3   Female  65-03-68139881
# 4     Male  14-11-40056582
# 5   Female  82-09-81734599
# 6     Male  26-03-50185868
# 7   Female  98-03-72394228
# 8     Male  68-01-80388982
# 9   Female  42-08-02614125
# 10    Male  15-06-41273848
# 11  Female  31-01-32329238
# 12    Male  73-02-11496212
# 13  Female  94-08-09289547
# 14    Male  98-09-16879291
# 15  Female  17-11-63791321
# 16    Male  71-03-35575299
# 17  Female  68-10-56792613
# 18    Male  28-09-97969690
# 19  Female  89-04-95690392
