# %%
def char_to_digit(char):
    if char.isdigit():
        return int(char)
    elif char.isalpha():
        return (ord(char.lower()) - ord('a') + 1) % 10
    else:
        return 0

def string_to_9_digits(s):
    digits = [char_to_digit(char) for char in s]
    numeric_string = ''.join(map(str, digits))
    
    # Ensure the string is exactly 9 digits long
    if len(numeric_string) > 13:
        return numeric_string[:13]
    else:
        return numeric_string.ljust(13, '0')

input_string = "dipeshpokharel 1982-08-20 shyamsundarpokharel"
numeric_string = string_to_9_digits(input_string)

# %%
numeric_string
# Out:
# '4965986518185'

# %%
string_to_9_digits("27854321")
# Out:
# '2785432100000'

# %%
import os
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os

# %%
final_Df = pd.read_csv('C:/Users/acer/PycharmProjects/Extenso_Assignment/Entity_Match/project/files/output_files/final_result.csv')

# %%
final_Df
# Out:
#     License Number    votersID                Temporary_Address  \
# 0   15-05-58353205  11116874.0        Gongabu, Kathmandu, Nepal
# 1   21-08-00435579  22259363.0         New Road, Pokhara, Nepal
# 2   93-12-35351480  33385241.0        Pulchowk, Lalitpur, Nepal
# 3   65-03-68139881  44475489.0       Bagbazar, Kathmandu, Nepal
# 4   14-11-40056582  55562139.0       Balkumari, Lalitpur, Nepal
# 5   82-09-81734599  66698214.0       Chabahil, Kathmandu, Nepal
# 6   26-03-50185868  77714635.0      Kumaripati, Lalitpur, Nepal
# 7   98-03-72394228  88847326.0  New Baneshwor, Kathmandu, Nepal
# 8   68-01-80388982  99953421.0         Boudha, Kathmandu, Nepal
# 9   42-08-02614125  10103847.0        Kalanki, Kathmandu, Nepal
# 10  15-06-41273848  11113982.0          Sanepa, Lalitpur, Nepal
# 11  31-01-32329238  12122547.0    Putalisadak, Kathmandu, Nepal
# 12  73-02-11496212  13135698.0        Tinkune, Kathmandu, Nepal
# 13  94-08-09289547  14147652.0     Sinamangal, Kathmandu, Nepal
# 14  98-09-16879291  15158963.0         Thamel, Kathmandu, Nepal
# 15  17-11-63791321  16169852.0      Jawalakhel, Lalitpur, Nepal
# 16  71-03-35575299  17175246.0      Maitighar, Kathmandu, Nepal
# 17  68-10-56792613  18183569.0    Buddhanagar, Kathmandu, Nepal
# 18  28-09-97969690  19194258.0          Naxal, Kathmandu, Nepal
# 19  89-04-95690392  20205417.0       Gaushala, Kathmandu, Nepal
# 20  14-11-40056582  55562139.0       Balkumari, Lalitpur, Nepal
# 21  26-03-50185868  77714635.0      Kumaripati, Lalitpur, Nepal
# 22  68-01-80388982  99953421.0         Boudha, Kathmandu, Nepal
# 23  98-09-16879291  15158963.0         Thamel, Kathmandu, Nepal
# 24  71-03-35575299  17175246.0      Maitighar, Kathmandu, Nepal
# 25  89-04-95690392  20205417.0       Gaushala, Kathmandu, Nepal
#
#                                               soup  \
# 0              ramthapa 1990-01-01 rambahadurthapa
# 1       sitashrestha 1991-02-02 hariprasadshrestha
# 2         harigurung 1992-03-03 gopalkrishnagurung
# 3             gitatamang 1993-04-04 shyamlaltamang
# 4              mohanlama 1994-05-05 krishnarajlama
# 5          radhamagar 1995-06-06 narayankumarmagar
# 6          krishnarai 1996-07-07 govindabahadurrai
# 7       saritasherpa 1997-08-08 shivanarayansherpa
# 8     bikashkarki 1998-09-09 bhagirathbahadurkarki
# 9    nishabhandari 1999-10-10 suryabahadurbhandari
# 10   aaravadhikari 2000-11-11 rajanbahaduradhikari
# 11        snehajoshi 2001-12-12 rameshbahadurjoshi
# 12         pratikshahi 1989-01-13 sureshkumarshahi
# 13     anjubhattarai 1988-02-14 dineshrajbhattarai
# 14  manishmaharjan 1987-03-15 bijaybahadurmaharjan
# 15               pujakc 1986-04-16 rameshbahadurkc
# 16       anilkhadka 1985-05-17 rajeshbahadurkhadka
# 17         ritarimal 1984-06-18 ganeshbahadurrimal
# 18   pratikshadahal 1983-07-19 santoshbahadurdahal
# 19   dipeshpokharel 1982-08-20 shyamsundarpokharel
# 20                       mohanlama  krishnarajlama
# 21                                    krishnarai
# 22              bikashkarki  bhagirathbahadurkarki
# 23                                manishmaharjan
# 24                                    anilkhadka
# 25             dipeshpokharel  shyamsundarpokharel
#
#                         Permanent_Address  \
# 0             Baluwatar, Kathmandu, Nepal
# 1                Lakeside, Pokhara, Nepal
# 2   Chitwan National Park, Chitwan, Nepal
# 3               Biratnagar, Morang, Nepal
# 4               Bharatpur, Chitwan, Nepal
# 5                Butwal, Rupandehi, Nepal
# 6               Hetauda, Makwanpur, Nepal
# 7                Janakpur, Dhanusa, Nepal
# 8                 Nepalgunj, Banke, Nepal
# 9                  Dharan, Sunsari, Nepal
# 10                Birtamode, Jhapa, Nepal
# 11              Dhangadhi, Kailali, Nepal
# 12                Itahari, Sunsari, Nepal
# 13            Bhaktapur, Bhaktapur, Nepal
# 14             Kirtipur, Kathmandu, Nepal
# 15              Lalitpur, Lalitpur, Nepal
# 16                   Ghorahi, Dang, Nepal
# 17                   Tansen, Palpa, Nepal
# 18                  Bidur, Nuwakot, Nepal
# 19                    Damak, Jhapa, Nepal
# 20              Bharatpur, Chitwan, Nepal
# 21              Hetauda, Makwanpur, Nepal
# 22                Nepalgunj, Banke, Nepal
# 23             Kirtipur, Kathmandu, Nepal
# 24                   Ghorahi, Dang, Nepal
# 25                    Damak, Jhapa, Nepal
#
#                                                source  Customer Code  \
# 0   final_result.csv, layout1.csv, layout2.csv, la...     21216874.0
# 1   final_result.csv, layout1.csv, layout2.csv, la...     22359363.0
# 2   final_result.csv, layout1.csv, layout2.csv, la...     33485241.0
# 3   final_result.csv, layout1.csv, layout2.csv, la...     45475489.0
# 4   final_result.csv, layout1.csv, layout2.csv, la...     56562139.0
# 5   final_result.csv, layout1.csv, layout2.csv, la...     67698214.0
# 6   final_result.csv, layout1.csv, layout2.csv, la...     78714635.0
# 7   final_result.csv, layout1.csv, layout2.csv, la...     89847326.0
# 8   final_result.csv, layout1.csv, layout2.csv, la...     91953421.0
# 9   final_result.csv, layout1.csv, layout2.csv, la...     10203847.0
# 10  final_result.csv, layout1.csv, layout2.csv, la...     12113982.0
# 11  final_result.csv, layout1.csv, layout2.csv, la...     13122547.0
# 12  final_result.csv, layout1.csv, layout2.csv, la...     13235698.0
# 13  final_result.csv, layout1.csv, layout2.csv, la...     14247652.0
# 14  final_result.csv, layout1.csv, layout2.csv, la...     15158964.0
# 15  final_result.csv, layout1.csv, layout2.csv, la...     16169853.0
# 16  final_result.csv, layout1.csv, layout2.csv, la...     17375246.0
# 17  final_result.csv, layout1.csv, layout2.csv, la...     18383569.0
# 18  final_result.csv, layout1.csv, layout2.csv, la...     19294258.0
# 19  final_result.csv, layout1.csv, layout2.csv, la...     20305417.0
# 20  final_result.csv, layout1.csv, layout2.csv, la...     56562139.0
# 21  final_result.csv, layout1.csv, layout2.csv, la...     78714635.0
# 22  final_result.csv, layout1.csv, layout2.csv, la...     91953421.0
# 23  final_result.csv, layout1.csv, layout2.csv, la...     15158964.0
# 24  final_result.csv, layout1.csv, layout2.csv, la...     17375246.0
# 25  final_result.csv, layout1.csv, layout2.csv, la...     20305417.0
#
#     SC Number           uuid              Father_Name  ...  Gender  \
# 0   001.01.01  8130816101990        Ram Bahadur Thapa  ...    Male
# 1   001.01.02  9901988590810     Hari Prasad Shrestha  ...  Female
# 2   001.01.03  8189718147019     Gopal Krishna Gurung  ...    Male
# 3   001.01.04  7901013147019         Shyam Lal Tamang  ...  Female
# 4   001.01.05  3581421310199         Krishna Raj Lama  ...    Male
# 5   001.01.06  8148131718019      Narayan Kumar Magar  ...  Female
# 6   001.01.07  1899841819019      Govinda Bahadur Rai  ...    Male
# 7   001.01.08  9189019858610     Shiva Narayan Sherpa  ...  Female
# 8   001.01.09  2911981181901  Bhagirath Bahadur Karki  ...    Male
# 9   001.01.10  4998128144189   Surya Bahadur Bhandari  ...  Female
# 10  001.01.11  1181214891189   Rajan Bahadur Adhikari  ...    Male
# 11  001.01.12  9458105989020     Ramesh Bahadur Joshi  ...  Female
# 12  001.01.13  6810919818901       Suresh Kumar Shahi  ...    Male
# 13  001.01.14  1401281001819     Dinesh Raj Bhattarai  ...  Female
# 14  001.01.15  3149983181801   Bijay Bahadur Maharjan  ...    Male
# 15  001.01.16  6101130198600        Ramesh Bahadur KC  ...  Female
# 16  001.01.17  1492181411019    Rajesh Bahadur Khadka  ...    Male
# 17  001.01.18  8901893120198     Ganesh Bahadur Rimal  ...  Female
# 18  001.01.19  6810919814181    Santosh Bahadur Dahal  ...    Male
# 19  001.01.20  4965986518185    Shyam Sundar Pokharel  ...  Female
# 20  001.01.05  3581421310018         Krishna Raj Lama  ...    Male
# 21  001.01.07  1899841819000      Govinda Bahadur Rai  ...    Male
# 22  001.01.09  2911981181900  Bhagirath Bahadur Karki  ...    Male
# 23  001.01.15  3149983181801   Bijay Bahadur Maharjan  ...    Male
# 24  001.01.17  1492181411000    Rajesh Bahadur Khadka  ...    Male
# 25  001.01.20  4965986518185    Shyam Sundar Pokharel  ...  Female
#
#             last_modified_date  Date of Birth      Citizenship Number  \
# 0   2024-05-30 11:47:40.457657     1990-01-01  624-93227-32431/660086
# 1   2024-05-30 11:47:40.460076     1991-02-02  747-42087-31417/584714
# 2   2024-05-30 11:47:40.462027     1992-03-03  389-45382-93886/821590
# 14  EFGH7890QR      QR345S      Gita Dhakal  Manish Maharjan       Ram Dhakal
# 15  STUV1234WX      TU678V       Laxmi Pant          Puja KC       Radha Pant
# 16  YZAB5678CD      WX901Y     Sarita Joshi      Anil Khadka       Amit Joshi
# 17  EFGH9012EF      ZA234B  Meena Bhattarai       Rita Rimal  Anita Bhattarai
# 18  IJKL3456GH      CD567E     Manju Gurung  Pratiksha Dahal      Sanu Gurung
# 19  MNOP7890IJ      FG890H        Rita Lama  Dipesh Pokharel        Hari Lama
# 20  VWXYZ7890N      MN345O    Kalpana Karki       Mohan Lama     Sarita Karki
# 21  EFGH5678RS      ST901U    Saru Shrestha      Krishna Rai   Laxmi Shrestha
# 22  ZABC3456DE      YZ567A     Lhamu Tamang     Bikash Karki      Pema Tamang
# 23  EFGH7890QR      QR345S      Gita Dhakal  Manish Maharjan       Ram Dhakal
# 24  YZAB5678CD      WX901Y     Sarita Joshi      Anil Khadka       Amit Joshi
# 25  MNOP7890IJ      FG890H        Rita Lama  Dipesh Pokharel        Hari Lama
#
#    votersAge
# 0       45.0
# 1       38.0
# 2       52.0
# 3       30.0
# 4       27.0
# 5       41.0
# 6       36.0
# 7       50.0
# 8       43.0
# 9       34.0
# 10      39.0
# 11      48.0
# 12      31.0
# 13      29.0
# 14      44.0
# 15      53.0
# 16      37.0
# 17      28.0
# 18      46.0
# 19      40.0
# 20      27.0
# 21      36.0
# 22      43.0
# 23      44.0
# 24      37.0
# 25      40.0
#
# [26 rows x 23 columns]

# %%
final_Df
# Out:
#     Customer Code National Id                                           soup1  \
# 0        21216874      AB123C             ramthapa 1990-01-01 rambahadurthapa
# 1        22359363      DE456F      sitashrestha 1991-02-02 hariprasadshrestha
# 2        33485241      GH789I        harigurung 1992-03-03 gopalkrishnagurung
# 3        45475489      JK012L            gitatamang 1993-04-04 shyamlaltamang
# 4        56562139      MN345O             mohanlama 1994-05-05 krishnarajlama
# 5        67698214      PQ678R         radhamagar 1995-06-06 narayankumarmagar
# 6        78714635      ST901U         krishnarai 1996-07-07 govindabahadurrai
# 7        89847326      VW234X      saritasherpa 1997-08-08 shivanarayansherpa
# 8        91953421      YZ567A    bikashkarki 1998-09-09 bhagirathbahadurkarki
# 9        10203847      BC890D   nishabhandari 1999-10-10 suryabahadurbhandari
# 10       12113982      EF123G   aaravadhikari 2000-11-11 rajanbahaduradhikari
# 11       13122547      HI456J        snehajoshi 2001-12-12 rameshbahadurjoshi
# 12       13235698      KL789M         pratikshahi 1989-01-13 sureshkumarshahi
# 13       14247652      NO012P     anjubhattarai 1988-02-14 dineshrajbhattarai
# 14       15158964      QR345S  manishmaharjan 1987-03-15 bijaybahadurmaharjan
# 15       16169853      TU678V               pujakc 1986-04-16 rameshbahadurkc
# 16       17375246      WX901Y       anilkhadka 1985-05-17 rajeshbahadurkhadka
# 17       18383569      ZA234B         ritarimal 1984-06-18 ganeshbahadurrimal
# 18       19294258      CD567E   pratikshadahal 1983-07-19 santoshbahadurdahal
# 19       20305417      FG890H   dipeshpokharel 1982-08-20 shyamsundarpokharel
#
#                 Temporary_Address       SpouseName  votersID Date of Birth  \
# 0                             NaN       Sita Thapa  11116874    1990-01-01
# 1        New Road, Pokhara, Nepal      Ravi Sharma  22259363    1991-02-02
# 2       Pulchowk, Lalitpur, Nepal    Maya Adhikari  33385241    1992-03-03
# 3      Bagbazar, Kathmandu, Nepal        Surya Rai  44475489    1993-04-04
# 4                             NaN     Sarita Karki  55562139    1994-05-05
# 5      Chabahil, Kathmandu, Nepal     Pemba Gurung  66698214    1995-06-06
# 6     Kumaripati, Lalitpur, Nepal   Laxmi Shrestha  77714635    1996-07-07
# 7                             NaN     Raj Maharjan  88847326    1997-08-08
# 8        Boudha, Kathmandu, Nepal      Pema Tamang  99953421    1998-09-09
# 9       Kalanki, Kathmandu, Nepal        Manish KC  10103847    1999-10-10
# 10                            NaN     Nisha Khadka  11113982    2000-11-11
# 11  Putalisadak, Kathmandu, Nepal      Kamal Magar  12122547    2001-12-12
# 12      Tinkune, Kathmandu, Nepal       Sita Yadav  13135698    1989-01-13
# 13   Sinamangal, Kathmandu, Nepal       Mina Bista  14147652    1988-02-14
# 14       Thamel, Kathmandu, Nepal       Ram Dhakal  15158963    1987-03-15
# 15    Jawalakhel, Lalitpur, Nepal       Radha Pant  16169852    1986-04-16
# 16    Maitighar, Kathmandu, Nepal       Amit Joshi  17175246    1985-05-17
# 17                            NaN  Anita Bhattarai  18183569    1984-06-18
# 18                            NaN      Sanu Gurung  19194258    1983-07-19
# 19                            NaN        Hari Lama  20205417    1982-08-20
#
#     votersAge  Gender                                             source  \
# 0          45    Male  layout1.csv, layout2.csv, layout3.csv, layout4...
# 1          38  Female  layout1.csv, layout2.csv, layout3.csv, layout4...
# 2          52    Male  layout1.csv, layout2.csv, layout3.csv, layout4...
# 3          30  Female  layout1.csv, layout2.csv, layout3.csv, layout4...
# 4          27    Male  layout1.csv, layout2.csv, layout3.csv, layout4...
# 5          41  Female  layout1.csv, layout2.csv, layout3.csv, layout4...
# 6          36    Male  layout1.csv, layout2.csv, layout3.csv, layout4...
# 7          50  Female  layout1.csv, layout2.csv, layout3.csv, layout4...
# 8          43    Male  layout1.csv, layout2.csv, layout3.csv, layout4...
# 9          34  Female  layout1.csv, layout2.csv, layout3.csv, layout4...
# 10         39    Male  layout1.csv, layout2.csv, layout3.csv, layout4...
# 11         48  Female  layout1.csv, layout2.csv, layout3.csv, layout4...
# 12         31    Male  layout1.csv, layout2.csv, layout3.csv, layout4...
# 13         29  Female  layout1.csv, layout2.csv, layout3.csv, layout4...
# 14         44    Male  layout1.csv, layout2.csv, layout3.csv, layout4...
# 15         53  Female  layout1.csv, layout2.csv, layout3.csv, layout4...
# 16         37    Male  layout1.csv, layout2.csv, layout3.csv, layout4...
# 17         28  Female  layout1.csv, layout2.csv, layout3.csv, layout4...
# 18         46    Male  layout1.csv, layout2.csv, layout3.csv, layout4...
# 19         40  Female  layout1.csv, layout2.csv, layout3.csv, layout4...
#
#     PAN_Number             Name               modified_date  SC Number  \
# 18                  Bidur, Nuwakot, Nepal    Santosh Bahadur Dahal
# 19                    Damak, Jhapa, Nepal    Shyam Sundar Pokharel
#
#         Mother Name  Customer ID  Mobile Number
# 0       Laxmi Thapa         3245     1234567890
# 1      Radha Sharma         3246     2345678901
# 2     Gita Adhikari         3247     3456789012
# 3          Mina Rai         3248     4567890123
# 4     Kalpana Karki         3249     5678901234
# 5       Nima Gurung         3250     6789012345
# 6     Saru Shrestha         3251     7890123456
# 7     Nanu Maharjan         3252     8901234567
# 8      Lhamu Tamang         3253     9012345678
# 9           Lila KC         3254      123456789
# 10   Chandra Khadka         3255     1234567800
# 11     Tulasa Magar         3256     2345678902
# 12      Ganga Yadav         3257     3456789013
# 13     Sunita Bista         3258     4567890124
# 14      Gita Dhakal         3259     5678901235
# 15       Laxmi Pant         3260     6789012346
# 16     Sarita Joshi         3261     7890123457
# 17  Meena Bhattarai         3262     8901234568
# 18     Manju Gurung         3263     9012345679
# 19        Rita Lama         3264      123456790

# %%
def get_file_names(directory):
    # Get the list of files in the specified directory
    files = os.listdir(directory)
    
    # Extract only the file names without the extensions
    file_names = [os.path.splitext(file)[0] for file in files]
    
    return file_names

# %%
name = get_file_names('C:/Users/acer/PycharmProjects/Extenso_Assignment/Entity_Match/project/files/input_files')

# %%
name
# Out:
# ['layout1', 'layout2', 'layout3', 'layout4', 'layout5']

# %%
def load_df(filename, file_path='../data'):
    full_path = os.path.join(file_path, f'{filename}.csv')
    try:
        df = pd.read_csv(full_path)
        print(f"File '{filename}.csv' loaded successfully from '{file_path}'.")
        return df
    except FileNotFoundError:
        print(f"Error: The file '{filename}.csv' was not found in the directory '{file_path}'.")
    except pd.errors.EmptyDataError:
        print(f"Error: The file '{filename}.csv' is empty.")
    except pd.errors.ParserError:
        print(f"Error: The file '{filename}.csv' could not be parsed.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# %%
layouts = []
for i,j in enumerate(name):
# Out:
#   Cell In[49], line 2
#     for i,j in enumerate(name):
#                                ^
# SyntaxError: incomplete input

# %%
def load_df_from_dir(dir_path):
    csv_files = [f for f in os.listdir(dir_path) if f.endswith(".csv")]
    layouts = []

    for csv_file in csv_files:
        file_path = os.path.join(dir_path, csv_file)
        df = pd.read_csv(file_path)
        layouts.append(df)
    
    return layouts

# %%
layouts = load_df_from_dir('C:/Users/acer/PycharmProjects/Extenso_Assignment/Entity_Match/project/files/input_files')

# %%
layouts[0]
# Out:
#     Customer Code             Name Date of Birth National Id  \
# 0        21216874        Ram Thapa    1990-01-01      AB123C
# 1        22359363    Sita Shrestha    1991-02-02      DE456F
# 2        33485241      Hari Gurung    1992-03-03      GH789I
# 3        45475489      Gita Tamang    1993-04-04      JK012L
# 4        56562139       Mohan Lama    1994-05-05      MN345O
# 5        67698214      Radha Magar    1995-06-06      PQ678R
# 6        78714635      Krishna Rai    1996-07-07      ST901U
# 7        89847326    Sarita Sherpa    1997-08-08      VW234X
# 8        91953421     Bikash Karki    1998-09-09      YZ567A
# 9        10203847   Nisha Bhandari    1999-10-10      BC890D
# 10       12113982   Aarav Adhikari    2000-11-11      EF123G
#     Mobile Number
# 0      1234567890
# 1      2345678901
# 2      3456789012
# 3      4567890123
# 4      5678901234
# 5      6789012345
# 6      7890123456
# 7      8901234567
# 8      9012345678
# 9       123456789
# 10     1234567800
# 11     2345678902
# 12     3456789013
# 13     4567890124
# 14     5678901235
# 15     6789012346
# 16     7890123457
# 17     8901234568
# 18     9012345679
# 19      123456790

# %%
def sanitize(df):
    return df.map(lambda x: x.replace(',', '').replace(' ', '').strip() if isinstance(x, str) else '' if pd.isna(x) else x)

# %%
layout_copies = []
for layout in layouts:
    try:
        if layout is not None:
            sanitized_layout = sanitize(layout.copy())
            layout_copies.append(sanitized_layout)
        else:
            layout_copies.append(None)
    except Exception as e:
        print(f"An error occurred while sanitizing a layout: {e}")
        layout_copies.append(None)

# %%
for i in range(len(layout_copies)):
    layout_copies[i] = sanitize(layout_copies[i])

# %%
def create_soup(df, df_, soup, soup_name):
    df[soup_name] = df_[soup].apply(lambda x: ' '.join(x.values.astype(str)).lower(), axis=1)

soup = ['Name', 'Date of Birth', 'Father_Name']

for i, j, k, in zip(layouts, layout_copies, range(len(layouts))):
    create_soup(i, j, soup, f"soup{k+1}")

# %%
def combine(A, B, soup_A, soup_B, threshold=0.3):
    # Initialize the TF-IDF Vectorizer
    tfidf = TfidfVectorizer(stop_words='english')
    
    # Combine the textual data for fitting the TF-IDF model
    combined_soup = pd.concat([A[soup_A], B[soup_B]], ignore_index=True)
    tfidf.fit(combined_soup)
    
    # Transform the textual data into TF-IDF matrices
    tfidf_matrix_A = tfidf.transform(A[soup_A])
    tfidf_matrix_B = tfidf.transform(B[soup_B])
    
    # Compute cosine similarity between the two matrices
    similarity = cosine_similarity(tfidf_matrix_A, tfidf_matrix_B)
    similarity_df = pd.DataFrame(similarity, index=A.index, columns=B.index)
    
    # Determine the index of the most similar row in B for each row in A
    max_idx_row = similarity_df.idxmax(axis=1)
    similarity_mask = similarity_df.max(axis=1) >= threshold
    
    # Initialize the combined DataFrame with A, ensuring all columns from both DataFrames
    combined_columns = list(set(A.columns) | set(B.columns))
    combined_data = pd.DataFrame(columns=combined_columns)
    
    # Merge the similar rows 
    for idx_A in A.index:
        if similarity_mask[idx_A]:
            idx_B = max_idx_row[idx_A]
            combined_row = A.loc[idx_A].combine_first(B.loc[idx_B])
        else:
            combined_row = A.loc[idx_A]
        combined_data = pd.concat([combined_data, combined_row.to_frame().T], ignore_index=True)
    
    # Append non-similar rows from B to A
    new_records = B.loc[~B.index.isin(max_idx_row[similarity_mask].values)]
    result = pd.concat([combined_data, new_records], ignore_index=True)
    result.drop(columns=soup_B, inplace=True)
    return result

# %%
result_12 = combine(layouts[0], layouts[1], 'soup1', 'soup2')
result_123 = combine(result_12, layouts[2], 'soup1', 'soup3')
result_1234 = combine(result_123, layouts[3], 'soup1', 'soup4')
final_result = combine(result_1234, layouts[4], 'soup1', 'soup5')

# %%
final_result
# Out:
#                   Temporary_Address  License Number      Citizenship Number  \
# 0         Gongabu, Kathmandu, Nepal  15-05-58353205  624-93227-32431/660086
# 7   TUVW9012XY      VW234X    8901234567    Sarita Sherpa  001.01.08
# 8   ZABC3456DE      YZ567A    9012345678     Bikash Karki  001.01.09
# 9   FGHI7890JK      BC890D     123456789   Nisha Bhandari  001.01.10
# 10  LMNO1234PL      EF123G    1234567800   Aarav Adhikari  001.01.11
# 11  QRST5678UM      HI456J    2345678902      Sneha Joshi  001.01.12
# 12  VWXY9012NZ      KL789M    3456789013     Pratik Shahi  001.01.13
# 13  ABCD3456OP      NO012P    4567890124   Anju Bhattarai  001.01.14
# 14  EFGH7890QR      QR345S    5678901235  Manish Maharjan  001.01.15
# 15  STUV1234WX      TU678V    6789012346          Puja KC  001.01.16
# 16  YZAB5678CD      WX901Y    7890123457      Anil Khadka  001.01.17
# 17  EFGH9012EF      ZA234B    8901234568       Rita Rimal  001.01.18
# 18  IJKL3456GH      CD567E    9012345679  Pratiksha Dahal  001.01.19
# 19  MNOP7890IJ      FG890H     123456790  Dipesh Pokharel  001.01.20
#
#    Customer Code       SpouseName  Gender
# 0       21216874       Sita Thapa    Male
# 1       22359363      Ravi Sharma  Female
# 2       33485241    Maya Adhikari    Male
# 3       45475489        Surya Rai  Female
# 4       56562139     Sarita Karki    Male
# 5       67698214     Pemba Gurung  Female
# 6       78714635   Laxmi Shrestha    Male
# 7       89847326     Raj Maharjan  Female
# 8       91953421      Pema Tamang    Male
# 9       10203847        Manish KC  Female
# 10      12113982     Nisha Khadka    Male
# 11      13122547      Kamal Magar  Female
# 12      13235698       Sita Yadav    Male
# 13      14247652       Mina Bista  Female
# 14      15158964       Ram Dhakal    Male
# 15      16169853       Radha Pant  Female
# 16      17375246       Amit Joshi    Male
# 17      18383569  Anita Bhattarai  Female
# 18      19294258      Sanu Gurung    Male
# 19      20305417        Hari Lama  Female

# %%
final_Df['soup1'].apply(string_to_9_digits)
# Out:
# 0     8130816101990
# 1     9901988590810
# 2     8189718147019
# 3     7901013147019
# 4     3581421310199
# 5     8148131718019
# 6     1899841819019
# 7     9189019858610
# 8     2911981181901
# 9     4998128144189
# 10    1181214891189
# 11    9458105989020
# 12    6810919818901
# 13    1401281001819
# 14    3149983181801
# 15    6101130198600
# 16    1492181411019
# 17    8901893120198
# 18    6810919814181
# 19    4965986518185
# Name: soup1, dtype: object

# %%
import pandas as pd
import numpy as np
import string

def generate_random_string(length):
    """Generate a random string of the given length."""
    letters_and_digits = string.ascii_letters + string.digits
    return ''.join(np.random.choice(list(letters_and_digits), size=length))

def generate_random_dataframe(num_rows, string_length):
    """Generate a DataFrame with a specified number of rows of random string data."""
    # Generate the random strings
    random_strings = [generate_random_string(string_length) for _ in range(num_rows)]
    
    # Create a DataFrame
    df = pd.DataFrame(random_strings, columns=['RandomString'])
    
    return df

# Example usage:
num_rows = 1000000 # 1 million rows
string_length = 15  # Length of each random string
df = generate_random_dataframe(num_rows, string_length)

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#       RandomString
# 0  JqDGV43jBxnMsPT
# 1  O75axrr7Y5v4svF
# 2  oRjDt3OcyoxwfFI
# 3  hIfGEG7gSii5qq4
# 4  SZ2MFgCclMvUCui
