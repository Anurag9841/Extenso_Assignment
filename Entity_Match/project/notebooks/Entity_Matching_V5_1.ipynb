# %% [markdown]
# ### Changelog
#
# - Need to create dynamic data loading/preprocessing/saving (for any number of files)

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from Levenshtein import distance
from datetime import datetime 
import os

# %% [markdown]
# ### Loading Dataset

# %%
def load_df_from_dir(dir_path):
    csv_files = [f for f in os.listdir(dir_path) if f.endswith(".csv")]
    layouts = []

    for csv_file in csv_files:
        file_path = os.path.join(dir_path, csv_file)
        df = pd.read_csv(file_path)
        df['source'] = os.path.splitext(csv_file)[0]
        layouts.append(df)
    
    return layouts

# %%
# layouts = load_df_from_dir('dataset_clean')
layouts = load_df_from_dir('../input_files')

# %% [markdown]
# ### Save DF to CSV

# %%
# import os
# import pandas as pd

# def save_dfs_to_csv(layouts, output_dir):

#     os.makedirs(output_dir, exist_ok=True)
    
#     for i, df in enumerate(layouts, start=1):
#         file_name = f"layout{i}.csv"
#         file_path = os.path.join(output_dir, file_name)
#         df.to_csv(file_path, index=False)
#         print(f"Saved {file_path}")

# %% [markdown]
# ### Data Preprocessing

# %%
for layout in layouts:
    layout['last_modified_date'] = datetime.now()

def sanitize(df):
    return df.map(lambda x: x.replace(',', '').replace(' ', '').strip() if isinstance(x, str) else '' if pd.isna(x) else x)
    
def create_soup(df, df_, soup, soup_name):
    df[soup_name] = df_[soup].apply(lambda x: ' '.join(x.values.astype(str)).lower(), axis=1)

layout_copies = [layout.copy() for layout in layouts]
soup = ['Name', 'Date of Birth', 'Father_Name']

for layout, layout_copy, in zip(layouts, layout_copies):
    layout_copy = sanitize(layout_copy)
    create_soup(layout, layout_copy, soup, "soup")

# %% [markdown]
# ### Entity Matching

# %%
def combine_layouts(A, B, metric='cosine', threshold=0.8):
    def calculate_similarity(A, B, metric):
        if metric == 'cosine':
            tfidf = TfidfVectorizer(stop_words='english')
            combined_soup = pd.concat([A['soup'], B['soup']], ignore_index=True)
            tfidf.fit(combined_soup)
            tfidf_matrix_A = tfidf.transform(A['soup'])
            tfidf_matrix_B = tfidf.transform(B['soup'])
            similarity = cosine_similarity(tfidf_matrix_A, tfidf_matrix_B)
            similarity_df = pd.DataFrame(similarity, index=A.index, columns=B.index)
            idx_row = similarity_df.idxmax(axis=1)
            similarity_mask = similarity_df.max(axis=1) > threshold
        else:
            distance_matrix = pd.DataFrame([[distance(a, b) for b in B['soup']] for a in A['soup']], index=A.index, columns=B.index)
            idx_row = distance_matrix.idxmin(axis=1)
            similarity_mask = distance_matrix.min(axis=1) <= threshold
        return idx_row, similarity_mask

    def merge_data(A, B, idx_row, similarity_mask):
        combined_columns = list(set(A.columns) | set(B.columns))
        combined_data = pd.DataFrame(columns=combined_columns)
        for idx_A in A.index:
            if similarity_mask[idx_A]:
                idx_B = idx_row[idx_A]
                combined_row = A.loc[idx_A].combine_first(B.loc[idx_B])
                combined_row['source'] = f"{A.loc[idx_A]['source']}, {B.loc[idx_B]['source']}"
                combined_row['last_modified_date'] = datetime.now()
            else:
                combined_row = A.loc[idx_A]
            combined_data = pd.concat([combined_data, combined_row.to_frame().T], ignore_index=True)
        new_records = B.loc[~B.index.isin(idx_row[similarity_mask].values)]
        return pd.concat([combined_data, new_records], ignore_index=True)

    idx_row, similarity_mask = calculate_similarity(A, B, metric)
    return merge_data(A, B, idx_row, similarity_mask)

# %% [markdown]
# ### Saving Results

# %% [markdown]
# #### Save Intermittent Result

# %%
# def save_layouts(layouts, save_path):
#     final_df = layouts[0]
#     results = [final_df] 

#     initial_part = "1"   
#     for i, df in enumerate(layouts[1:], start=2):
#         final_df = combine_layouts(final_df, df)
#         results.append(final_df)
        
#         initial_part += str(i)
#         final_df.to_csv(f"./{save_path}/result{initial_part}.csv", index=False)
    
#     return final_df, results

# %%
# final_df, results = save_layouts(layouts, 'results')

# %% [markdown]
# #### Save final result only

# %%
def char_to_digit(char):
    if char.isdigit():
        return int(char)
    elif char.isalpha():
        return (ord(char.lower()) - ord('a') + 1) % 10
    else:
        return 0

def string_to_digits(s):
    digits = [char_to_digit(char) for char in s]
    numeric_string = ''.join(map(str, digits))
    
    # Ensure the string is exactly 9 digits long
    if len(numeric_string) > 13:
        return numeric_string[:13]
    else:
        return numeric_string.ljust(13, '0')

# %%
def save_layouts(layouts, save_path):
    final_df = layouts[0]

    for df in layouts[1:]:
        final_df = combine_layouts(final_df, df)
    
    final_df['uuid'] = final_df['soup'].apply(string_to_digits)
    final_result_path = os.path.join(save_path, 'final_result.csv')
    final_df.to_csv(final_result_path, index=False)
    return final_df

# %%
final_df = save_layouts(layouts, '../input_files')

# %%
final_df
# Out:
#                                          source  \
# 0   layout1, layout2, layout3, layout4, layout5
# 1   layout1, layout2, layout3, layout4, layout5
# 2   layout1, layout2, layout3, layout4, layout5
# 3   layout1, layout2, layout3, layout4, layout5
# 4            layout1, layout2, layout3, layout4
# 5   layout1, layout2, layout3, layout4, layout5
# 6            layout1, layout2, layout3, layout4
# 7   layout1, layout2, layout3, layout4, layout5
# 8            layout1, layout2, layout3, layout4
# 9   layout1, layout2, layout3, layout4, layout5
# 10  layout1, layout2, layout3, layout4, layout5
# 11  layout1, layout2, layout3, layout4, layout5
# 12  layout1, layout2, layout3, layout4, layout5
# 13  layout1, layout2, layout3, layout4, layout5
# 14           layout1, layout2, layout3, layout4
# 15  layout1, layout2, layout3, layout4, layout5
# 16           layout1, layout2, layout3, layout4
# 17  layout1, layout2, layout3, layout4, layout5
# 18  layout1, layout2, layout3, layout4, layout5
# 19           layout1, layout2, layout3, layout4
# 20                                      layout5
# 21                                      layout5
# 22                                      layout5
# 23                                      layout5
# 24                                      layout5
# 25                                      layout5
#
#                         Permanent_Address votersAge Mobile Number  \
# 0             Baluwatar, Kathmandu, Nepal        45    1234567890
# 1                Lakeside, Pokhara, Nepal        38    2345678901
# 2   Chitwan National Park, Chitwan, Nepal        52    3456789012
# 3               Biratnagar, Morang, Nepal        30    4567890123
# 4               Bharatpur, Chitwan, Nepal        27    5678901234
# 5                Butwal, Rupandehi, Nepal        41    6789012345
#
#         Citizenship Number  PAN_Number Customer Code  ...  Gender  \
# 0   624-93227-32431/660086  ABCDE1234F      21216874  ...    Male
# 1   747-42087-31417/584714  FGHIJ5678K      22359363  ...  Female
# 2   389-45382-93886/821590  LMNOP9012L      33485241  ...    Male
# 3   571-38785-99733/440035  QRSTU3456M      45475489  ...  Female
# 4                      NaN  VWXYZ7890N      56562139  ...    Male
# 5   033-51347-62581/380746  ABCD1234PQ      67698214  ...  Female
# 6                      NaN  EFGH5678RS      78714635  ...    Male
# 7   323-37869-95909/623481  TUVW9012XY      89847326  ...  Female
# 8                      NaN  ZABC3456DE      91953421  ...    Male
# 9   272-28301-42325/881177  FGHI7890JK      10203847  ...  Female
# 10  575-80644-44438/883300  LMNO1234PL      12113982  ...    Male
# 11  599-66155-86484/518801  QRST5678UM      13122547  ...  Female
# 12  371-38746-28131/634277  VWXY9012NZ      13235698  ...    Male
# 13  506-21915-16175/214975  ABCD3456OP      14247652  ...  Female
# 14                     NaN  EFGH7890QR      15158964  ...    Male
# 15  697-65333-88172/166613  STUV1234WX      16169853  ...  Female
# 16                     NaN  YZAB5678CD      17375246  ...    Male
# 17  542-42953-82512/112038  EFGH9012EF      18383569  ...  Female
# 18  697-25014-99353/663054  IJKL3456GH      19294258  ...    Male
# 19                     NaN  MNOP7890IJ      20305417  ...  Female
# 20  864-17331-40021/961722         NaN           NaN  ...     NaN
# 21  068-37653-84341/852787         NaN           NaN  ...     NaN
# 22  406-94259-70142/249811         NaN           NaN  ...     NaN
# 23  157-92240-30969/930555         NaN           NaN  ...     NaN
# 24  395-60019-88104/590785         NaN           NaN  ...     NaN
# 25  769-44973-94012/456699         NaN           NaN  ...     NaN
#
#                 Father_Name Blood Group  License Number  SC Number  \
# 0         Ram Bahadur Thapa         AB+  15-05-58353205  001.01.01
# 1      Hari Prasad Shrestha         AB-  21-08-00435579  001.01.02
# 2      Gopal Krishna Gurung          B-  93-12-35351480  001.01.03
# 3          Shyam Lal Tamang          A-  65-03-68139881  001.01.04
# 4          Krishna Raj Lama         NaN             NaN  001.01.05
# 5       Narayan Kumar Magar          B-  82-09-81734599  001.01.06
# 6       Govinda Bahadur Rai         NaN             NaN  001.01.07
# 7      Shiva Narayan Sherpa          A-  98-03-72394228  001.01.08
# 8   Bhagirath Bahadur Karki         NaN             NaN  001.01.09
# 9    Surya Bahadur Bhandari          A-  42-08-02614125  001.01.10
# 10   Rajan Bahadur Adhikari          O+  15-06-41273848  001.01.11
# 11     Ramesh Bahadur Joshi         AB+  31-01-32329238  001.01.12
# 12       Suresh Kumar Shahi          O-  73-02-11496212  001.01.13
# 13     Dinesh Raj Bhattarai         AB-  94-08-09289547  001.01.14
# 14   Bijay Bahadur Maharjan         NaN             NaN  001.01.15
# 15        Ramesh Bahadur KC         AB-  17-11-63791321  001.01.16
# 16    Rajesh Bahadur Khadka         NaN             NaN  001.01.17
# 17     Ganesh Bahadur Rimal          B-  68-10-56792613  001.01.18
# 18    Santosh Bahadur Dahal         AB+  28-09-97969690  001.01.19
# 19    Shyam Sundar Pokharel         NaN             NaN  001.01.20
# 20         Krishna Raj Lama          A+  14-11-40056582        NaN
# 21                      NaN         AB+  26-03-50185868        NaN
# 22  Bhagirath Bahadur Karki          B-  68-01-80388982        NaN
# 23                      NaN          B+  98-09-16879291        NaN
# 24                      NaN         AB-  71-03-35575299        NaN
# 25    Shyam Sundar Pokharel          A-  89-04-95690392        NaN
#
#    Customer ID National Id             Name       SpouseName           uuid
# 0         3245      AB123C        Ram Thapa       Sita Thapa  8130816101990
# 1         3246      DE456F    Sita Shrestha      Ravi Sharma  9901988590810
# 2         3247      GH789I      Hari Gurung    Maya Adhikari  8189718147019
# 3         3248      JK012L      Gita Tamang        Surya Rai  7901013147019
# 4         3249      MN345O       Mohan Lama     Sarita Karki  3581421310199
# 5         3250      PQ678R      Radha Magar     Pemba Gurung  8148131718019
# 6         3251      ST901U      Krishna Rai   Laxmi Shrestha  1899841819019
# 7         3252      VW234X    Sarita Sherpa     Raj Maharjan  9189019858610
# 8         3253      YZ567A     Bikash Karki      Pema Tamang  2911981181901
# 9         3254      BC890D   Nisha Bhandari        Manish KC  4998128144189
# 10        3255      EF123G   Aarav Adhikari     Nisha Khadka  1181214891189
# 11        3256      HI456J      Sneha Joshi      Kamal Magar  9458105989020
# 12        3257      KL789M     Pratik Shahi       Sita Yadav  6810919818901
# 13        3258      NO012P   Anju Bhattarai       Mina Bista  1401281001819
# 14        3259      QR345S  Manish Maharjan       Ram Dhakal  3149983181801
# 15        3260      TU678V          Puja KC       Radha Pant  6101130198600
# 16        3261      WX901Y      Anil Khadka       Amit Joshi  1492181411019
# 17        3262      ZA234B       Rita Rimal  Anita Bhattarai  8901893120198
# 18        3263      CD567E  Pratiksha Dahal      Sanu Gurung  6810919814181
# 19        3264      FG890H  Dipesh Pokharel        Hari Lama  4965986518185
# 20         NaN         NaN       Mohan Lama              NaN  3581421310018
# 21         NaN         NaN      Krishna Rai              NaN  1899841819000
# 22         NaN         NaN     Bikash Karki              NaN  2911981181900
# 23         NaN         NaN  Manish Maharjan              NaN  3149983181801
# 24         NaN         NaN      Anil Khadka              NaN  1492181411000
# 25         NaN         NaN  Dipesh Pokharel              NaN  4965986518185
#
# [26 rows x 23 columns]

# %% [markdown]
# #### Save final_result and delete source files if successful

# %%
# import os
# import glob

# def save_layouts(layouts, save_path, save_filename):
#     final_df = layouts[0]

#     for df in layouts[1:]:
#         final_df = combine_layouts(final_df, df)
    
#     final_result_path = os.path.join(save_path, save_filename)
    
#     try:
#         final_df.to_csv(final_result_path, index=False)
#     except Exception as e:
#         print(f"Error saving final result: {e}")
#         return None

#     # If save is successful, delete all other files in save_path except final_result
#     files = glob.glob(os.path.join(save_path, '*'))
#     for f in files:
#         if f != final_result_path:
#             os.remove(f)

#     return final_df

# %%
# final_df = save_layouts(layouts, 'results', 'final_result.csv')
